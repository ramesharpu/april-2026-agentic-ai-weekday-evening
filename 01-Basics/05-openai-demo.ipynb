# %%
# install openai
pip install openai dotenv

# %%
# define the requirments.txt file with packages that needs to be installed
pip install -Ur requirements.txt

# %%
#import statement
from openai import OpenAI
from dotenv import load_dotenv
import os

# Loading the .evn file
load_dotenv()

# adding the key
api_key = os.environ.get("OPENAI_KEY")

# Creating an instance of the client
client = OpenAI(api_key=api_key)

# Response coding
response = client.responses.create(
    model="gpt-5.4-mini",
    input="Write a short bedtime story about a unicorn."
)

print(response.output_text)

# %%
#import statement
from openai import OpenAI
from dotenv import load_dotenv
import os

# Loading the .evn file
def load_env_file():
    load_dotenv()

# adding the key
def llm_object():
    load_env_file()
    api_key = os.environ.get("OPENAI_KEY")

    # Creating an instance of the client
    client = OpenAI(api_key=api_key)

    return client

# Response coding
def request():
    client = llm_object()
    response = client.responses.create(
        model="gpt-5.4-mini",
        input="Write a short bedtime story about a unicorn."
    )
    return response.output_text)

request()

# %%
#import statement
from openai import OpenAI
from dotenv import load_dotenv
import os

class Demo:
    # Loading the .evn file
    def load_env_file():
        load_dotenv()
    
    # adding the key
    def llm_object():
        load_env_file()
        api_key = os.environ.get("OPENAI_KEY")
    
        # Creating an instance of the client
        client = OpenAI(api_key=api_key)
    
        return client
    
    # Response coding
    def request():
        client = llm_object()
        response = client.responses.create(
            model="gpt-5.4-mini",
            input="Write a short bedtime story about a unicorn."
        )
        return response.output_text)

obj = Demo()
obj.request()
